# %% [markdown]
# <a href="https://colab.research.google.com/github/harsha-9977/AIML/blob/main/training.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# DataTypes
#
# primitive
# non primitive
#
#
# primitive are :
# byte short int long float double boolean and character
# Non primitve :
# string arrays and classes
#
# stores whole numbers from
#
# byte  -128 to 127
# short -32768 to 32767
# integer (int) -2147483648 to 2147483647
# lomg -9223372036854775808 to 9223372036854775807
# float 6 to 7 decimALS
# DOUBLE 15 to 16 decimal digits
# boolean True or false
# char single character ''
#
# numbers integer type
#           byte short int long
#         floating type in numbers
#           float double scientific numbers with e or E to indicate power of 10
#
# String text sequence ""
# -------------------------------------------------------------------------------
#
# Non primitive
#
# reference types because they refer to the objects
#
#
# primitive
#
# predefined
# sttarts with lower case
# it cant be null
#
# Non primitive
#
# created by programmer except string
# used to call methods to perform certain operation
# it can be null
#
# -------------------------------------------------------------------------------
# Java Type casting
#
# when we assign the value of one primitve type to other
# widening casting  automatic when passing small type with larger type
# narrow casting  manual process its done by placing () in front of a value
#
# ------------------------------------------------------------------------------
#
# Java operator
#
# arithmetic
#   7 + - * / % ++ --
# assignment
#   = += -= *= /=
# logical
#   && || !
# comparison
#   == != >= <= > <
# bitwise
#   & | ^
#
# Java Strings
#
# string length a string in java is actually an object which contains methods that can perform certain operations on strings length()
# toUpperCase() toLowerCase()
#
# finding a character in a string
# indexOf() returns the index/ position of the first occurance of a specified char in string including white space
#
#
# Java
# strings must return within the quotes
#   the solution to avoid to this problem is \' \" \\
#
# Java math class
#   -mathematical task on a number Math.max(x,y) Math.min Math.sqrt Math.abs
#
#
# object is created at run time
# java.lang.object toString()
# java.lang
#
#
# 30% of discount age above 50
#
# ------------------------------------------------------------------------------
#
#
# Java boolean
#
# True False
#
# Boolean expressions return true or false
#
# Java if else < <= > >= == !=
#   1 use if to execute a specific block of code with condition is True
#       else when it is false
#       else if new condition like other condition if first condition is false
#       Switch alternatice blocks of code
#
#       ternery operator short hand if else
#
#       3 operands
#
# java switch instead of many if else
#   it selects one of many blocks to be executed
#
# switch experssion evaluated one
#
# break and default are the keyword for this
#
# the break keyword
#
# default keyword specifies some code to run if there is no match
#
# ---------------------------------------------------------------------------------
# Examples
#
# java arithmetic operators
# a = 25
# b = 30
#
#
# point system in a game
# player can earn points with each action
#
# imagine u r designing an online voting registered user or above 18
